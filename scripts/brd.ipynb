# %%
"""Simulation of infections for different scenarios."""
import os
import covid19sim.coronalib as cl
import pandas as pd 
import numpy as np
import plotly.express as px
import datetime
import plotly.graph_objects as go
from plotly.offline import plot
from plotly.subplots import make_subplots

# %%
w = 1
age, agegroup, gender, contacts, drate, hnr, persons = cl.makepop("current",83000000/w)
# Einlesen der realisierten Daten
brd = pd.read_excel("./brd_dat.xlsx")
brd["Meldedatum"] = brd["Meldedatum"].dt.date
brd["Datum"] = brd["Meldedatum"]
brd["Fälle"] = brd["Fälle"] / w 
brd["Fälle_kum"] = brd["Fälle_kum"] / w

# %%
day0date = datetime.date(2020, 3, 8)
r_change = {}
r_change['2020-01-01'] = 0.4*8 * contacts/np.mean(contacts)
r_change['2020-03-08'] = 0.24*8 * contacts/np.mean(contacts)
r_change['2020-03-16'] = 0.15*8 * contacts/np.mean(contacts)
r_change['2020-03-23'] = 0.6 * contacts/np.mean(contacts)
r_change['2020-05-04'] = 0.7 * contacts/np.mean(contacts)

com_attack_rate = {}
com_attack_rate["2020-01-1"] = 0.0
state, statesum, infections, day0, rnow, args, gr = cl.sim(
        age, drate, nday=180, prob_icu=0.009, day0cumrep=3600/w,
        mean_days_to_icu=16, mean_duration_icu=14,
        mean_time_to_death=21,
        mean_serial=7.5, std_serial=3.0, immunt0=0.0, ifr=0.003,
        long_term_death=False, hnr=None, com_attack_rate=com_attack_rate,
        r_change=r_change, simname="Basis NRW ohne Community Attack",
        datadir=".",
        realized=brd, rep_delay=13, alpha=0.125, day0date=day0date)

cl.plotoverview(gr, args)
# Out:
#                               Peaktag  Peakwert      Summe  Mittleres Alter  \
# Erwartete Neu-Infektionen  2020-03-16   46633.0  1231475.0        39.189164
# Erwartete Neu-Meldefälle   2020-03-28    5245.0   153669.0              NaN
# ICU                        2020-04-09    2681.0    97536.0              NaN
# Erwartete Neu-Intensiv     2020-04-06     225.0     7047.0        75.818930
# Erwartete neue Tote        2020-04-07      82.0     2331.0        75.844702
#
#                            Median Alter
# Erwartete Neu-Infektionen          39.0
# Erwartete Neu-Meldefälle            NaN
# ICU                                 NaN
# Erwartete Neu-Intensiv             80.0
# Erwartete neue Tote                80.0
# Simulation time: 661.9927916526794
# <div>
#
#
#             <div id="0557899d-d372-4aa2-9ca1-202fb50765fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0557899d-d372-4aa2-9ca1-202fb50765fa")) {
#                     Plotly.newPlot(
#                         '0557899d-d372-4aa2-9ca1-202fb50765fa',
#                         [{"mode": "lines", "name": "Erwartete Neu-Meldef\u00e4lle", "type": "scatter", "x": ["2020-03-01", "2020-03-02", "2020-03-03", "2020-03-04", "2020-03-05", "2020-03-06", "2020-03-07", "2020-03-08", "2020-03-09", "2020-03-10", "2020-03-11", "2020-03-12", "2020-03-13", "2020-03-14", "2020-03-15", "2020-03-16", "2020-03-17", "2020-03-18", "2020-03-19", "2020-03-20", "2020-03-21", "2020-03-22", "2020-03-23", "2020-03-24", "2020-03-25", "2020-03-26", "2020-03-27", "2020-03-28", "2020-03-29", "2020-03-30", "2020-03-31", "2020-04-01", "2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05", "2020-04-06", "2020-04-07", "2020-04-08", "2020-04-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-04-14", "2020-04-15", "2020-04-16", "2020-04-17", "2020-04-18", "2020-04-19", "2020-04-20", "2020-04-21", "2020-04-22", "2020-04-23", "2020-04-24", "2020-04-25", "2020-04-26", "2020-04-27", "2020-04-28", "2020-04-29", "2020-04-30", "2020-05-01", "2020-05-02", "2020-05-03", "2020-05-04", "2020-05-05", "2020-05-06", "2020-05-07", "2020-05-08", "2020-05-09", "2020-05-10", "2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26", "2020-05-27", "2020-05-28", "2020-05-29", "2020-05-30", "2020-05-31", "2020-06-01", "2020-06-02", "2020-06-03", "2020-06-04", "2020-06-05", "2020-06-06", "2020-06-07", "2020-06-08", "2020-06-09", "2020-06-10", "2020-06-11", "2020-06-12", "2020-06-13", "2020-06-14", "2020-06-15", "2020-06-16", "2020-06-17", "2020-06-18", "2020-06-19", "2020-06-20", "2020-06-21", "2020-06-22", "2020-06-23", "2020-06-24", "2020-06-25", "2020-06-26", "2020-06-27", "2020-06-28", "2020-06-29", "2020-06-30", "2020-07-01", "2020-07-02", "2020-07-03", "2020-07-04", "2020-07-05", "2020-07-06", "2020-07-07", "2020-07-08", "2020-07-09"], "xaxis": "x", "y": [175.0, 207.0, 243.0, 282.0, 328.0, 387.0, 457.0, 533.0, 622.0, 729.0, 852.0, 1000.0, 1175.0, 1375.0, 1601.0, 1865.0, 2185.0, 2569.0, 2987.0, 3251.0, 3173.0, 3116.0, 3390.0, 3852.0, 4337.0, 4785.0, 5161.0, 5245.0, 4831.0, 4446.0, 4506.0, 4789.0, 5065.0, 5227.0, 4979.0, 4090.0, 3239.0, 2925.0, 2877.0, 2844.0, 2766.0, 2643.0, 2490.0, 2317.0, 2151.0, 2009.0, 1886.0, 1777.0, 1671.0, 1570.0, 1475.0, 1386.0, 1302.0, 1220.0, 1143.0, 1068.0, 1000.0, 939.0, 885.0, 835.0, 787.0, 739.0, 691.0, 645.0, 604.0, 568.0, 535.0, 502.0, 470.0, 439.0, 414.0, 394.0, 371.0, 347.0, 325.0, 307.0, 295.0, 291.0, 286.0, 273.0, 258.0, 245.0, 233.0, 222.0, 211.0, 200.0, 190.0, 183.0, 176.0, 168.0, 159.0, 152.0, 147.0, 141.0, 136.0, 129.0, 122.0, 117.0, 113.0, 108.0, 101.0, 96.0, 91.0, 86.0, 83.0